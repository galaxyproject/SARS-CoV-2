# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('../current_metadata_ena.tsv', sep='\t')
df.index = df.run_accession
# Out:
# /opt/hostedtoolcache/Python/3.8.6/x64/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (2,5,9,21,27,31,35,49,51,52,53,59,60) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
date = pd.read_csv('../accession_and_date.tsv', sep='\t', header=None)

# %%
date.columns = ['accession', 'date']

# %%
by_date = date.date.value_counts()

# %%
by_date.sort_index().plot(kind='bar', figsize=(20, 8)).set_title("All published SRA/ENA accessions by date")
# Out:
# Text(0.5, 1.0, 'All published SRA/ENA accessions by date')

# %%
date['is_sra'] = date.accession.str.startswith('SRR')

# %%
by_date_by_center = date.groupby(['date', 'is_sra']).count().reset_index()

# %%
fig, ax = plt.subplots(figsize=(20, 8))
ax = sns.barplot(x='date', y='accession', hue='is_sra', data=by_date_by_center, ax=ax)
ax.set_title('Accessions published by SRA/ENA by date')
for item in ax.get_xticklabels():
    item.set_rotation(90)

# %%
instruments = df.groupby(['instrument_platform', 'instrument_model']).count()['accession'].reset_index()
instruments
# Out:
#    instrument_platform            instrument_model  accession
# 0               BGISEQ                  BGISEQ-500          1
# 1            CAPILLARY  AB 3730xL Genetic Analyzer          7
# 2             ILLUMINA    Illumina Genome Analyzer          3
# 3             ILLUMINA         Illumina HiSeq 1500         13
# 4             ILLUMINA         Illumina HiSeq 2000          4
# 5             ILLUMINA         Illumina HiSeq 2500       2465
# 6             ILLUMINA         Illumina HiSeq 4000         56
# 7             ILLUMINA              Illumina MiSeq       9300
# 8             ILLUMINA            Illumina MiniSeq         39
# 9             ILLUMINA       Illumina NovaSeq 6000      21009
# 10            ILLUMINA           Illumina iSeq 100        391
# 11            ILLUMINA                 NextSeq 500       4805
# 12            ILLUMINA                 NextSeq 550      12102
# 13            ILLUMINA                 unspecified        179
# 14         ION_TORRENT             Ion Torrent PGM          1
# 15         ION_TORRENT              Ion Torrent S5        420
# 16         ION_TORRENT           Ion Torrent S5 XL         14
# 17     OXFORD_NANOPORE                     GridION      10827
# 18     OXFORD_NANOPORE                      MinION       2744
# 19     OXFORD_NANOPORE                  PromethION         57

# %%
df.groupby(['library_strategy', 'instrument_platform']).count()['accession'].reset_index()
# Out:
#     library_strategy instrument_platform  accession
# 0           AMPLICON           CAPILLARY          7
# 1           AMPLICON            ILLUMINA      43699
# 2           AMPLICON         ION_TORRENT        411
# 3           AMPLICON     OXFORD_NANOPORE      13151
# 4              OTHER            ILLUMINA         75
# 5            RNA-Seq            ILLUMINA       3338
# 6            RNA-Seq         ION_TORRENT          6
# 7            RNA-Seq     OXFORD_NANOPORE          5
# 8   Targeted-Capture            ILLUMINA        711
# 9                WGA              BGISEQ          1
# 10               WGA            ILLUMINA        249
# 11               WGS            ILLUMINA       2294
# 12               WGS         ION_TORRENT         18
# 13               WGS     OXFORD_NANOPORE        472

# %%
df.country.str.replace(':.*', '').value_counts().plot(kind='bar', figsize=(20, 8)).set_title("Desposited accessions by Country")
# Out:
# Text(0.5, 1.0, 'Desposited accessions by Country')

# %%
df['sex'] = df.apply(axis=1, func=lambda row: row['host_sex'] or row['submitted_host_sex'])
df.sex.value_counts()
# Out:
# male      3614
# female    3515
# Name: sex, dtype: int64

# %%
df.isolation_source.value_counts()
# Out:
# nasopharyngeal swab                                                                     5229
# human                                                                                   1537
# patient isolate                                                                         1147
# not collected                                                                            584
# nasopharyngeal swabs                                                                     584
# Nasopharyngeal/oropharyngeal swab                                                        513
# nasal swab                                                                               458
# Oro-pharyngeal swab                                                                      401
# not provided                                                                             334
# nasopharyngeal                                                                           258
# not collected&apos;                                                                      204
# hospital                                                                                 173
# sputum                                                                                    97
# nasopharynx                                                                               65
# Diagnostic Swab                                                                           65
# oropharynx swab                                                                           56
# clinical sample                                                                           43
# oralpharyngeal                                                                            27
# Nasal-Swab and Oro-pharyngeal swab                                                        23
# swab                                                                                      17
# strain BavPat1                                                                            13
# oropharyngeal swab                                                                        10
# bronchoalveolar lavage fluid(BALF)                                                         8
# Wuhan                                                                                      8
# USA, WA                                                                                    8
# Nasopharyngeal/throat swab                                                                 7
# Naso-pharyngeal swab                                                                       6
# nose-oropharynx                                                                            6
# passage                                                                                    6
# Vero E6 cells supernatant                                                                  5
# Oropharyngeal swab                                                                         5
# Cercopithecus aethiops                                                                     5
# Naso and/or oropharyngeal swab                                                             5
# Nasopharyngeal swabs                                                                       5
# Seattle, WA                                                                                4
# oropharynx                                                                                 4
# culture                                                                                    4
# throat swab                                                                                4
# ropharyngeal swab                                                                          3
# Deep throat saliva                                                                         3
# Biological sample                                                                          2
# tracheal swab                                                                              2
# saliva                                                                                     2
# Siena University hospital                                                                  2
# COVID-19 symptomatic patient                                                               2
# Combined nasopharyngeal and oropharyngeal swab                                             2
# bronchoalveolar lavage                                                                     2
# USA                                                                                        1
# Jingzhou                                                                                   1
# cell culure                                                                                1
# Nasopharyngeal sample                                                                      1
# oropharyngeal swab from positive patient in general military hospital in Cairo-Egypt       1
# Tianmen                                                                                    1
# NP/OP swab                                                                                 1
# respiratory nasopharyngeal sample                                                          1
# Biological Sample                                                                          1
# feca swab                                                                                  1
# Name: isolation_source, dtype: int64

# %%
ax = df.collection_date.value_counts().sort_index().plot(kind='bar', figsize=(20, 8))
ax.set_title('Collection by date')
for label in ax.xaxis.get_ticklabels()[::2]:
    label.set_visible(False)
