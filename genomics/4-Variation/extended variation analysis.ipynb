# %%
# %matplotlib widget

# Set display to the full length

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import ipywidgets as widgets
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from ipywidgets import interact
from ipywidgets import interactive

from matplotlib.widgets import Button
from matplotlib.text import Annotation

from Bio import SeqIO
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# Read in variant list and genbank file with records

df = pd.read_csv('variant_list.tsv', sep='\t')
df.columns = [c if not c.startswith('EFF[*].') else c[7:] for c in df.columns]
record = SeqIO.read('NC_045512.2.genbank','genbank')

# Add a column with a textual representation of each variant
df['textual_variant'] = df['POS'].astype(str) + df['REF'] + '/' + df['ALT']

# Add a column with the delta of higest to lowest AF
min_max_af = df.groupby('textual_variant').agg({'AF': (min, max)})
af_delta = min_max_af['AF']['max'] - min_max_af['AF']['min']
df.index = df['textual_variant']
df.loc[af_delta.index, 'AF_delta'] = af_delta

# %%
df
# Out:
#                       Sample      CHROM    POS REF ALT   DP        AF  SB  \
# textual_variant
# 1409C/T          SRR10903401  NC_045512   1409   C   T  126  0.039683   1
# 1821G/A          SRR10903401  NC_045512   1821   G   A   93  0.096774   0
# 1895G/A          SRR10903401  NC_045512   1895   G   A  106  0.037736   0
# 2407G/T          SRR10903401  NC_045512   2407   G   T  123  0.024390   0
# 3379A/G          SRR10903401  NC_045512   3379   A   G  121  0.024793   0
# ...                      ...        ...    ...  ..  ..  ...       ...  ..
# 29515T/A         SRR11454615  NC_045512  29515   T   A  172  0.029070   1
# 29515T/G         SRR11454615  NC_045512  29515   T   G  172  0.029070   1
# 29556A/G         SRR11454615  NC_045512  29556   A   G  170  0.023529   0
# 29573G/A         SRR11454615  NC_045512  29573   G   A  219  0.018265   0
# 29761A/G         SRR11454615  NC_045512  29761   A   G  413  0.014528   0
#
#                          DP4    IMPACT  FUNCLASS                 EFFECT  \
# textual_variant
# 1409C/T            67,54,2,3  MODERATE  MISSENSE  NON_SYNONYMOUS_CODING
# 1821G/A            48,36,5,4  MODERATE  MISSENSE  NON_SYNONYMOUS_CODING
# 1895G/A            51,51,2,2  MODERATE  MISSENSE  NON_SYNONYMOUS_CODING
# 2407G/T            57,63,1,2  MODERATE  MISSENSE  NON_SYNONYMOUS_CODING
# 3379A/G            56,62,1,2       LOW    SILENT      SYNONYMOUS_CODING
# ...                      ...       ...       ...                    ...
# 29515T/A           68,94,1,4       LOW    SILENT      SYNONYMOUS_CODING
# 29515T/G           68,94,1,4       LOW    SILENT      SYNONYMOUS_CODING
# 29556A/G           74,92,2,2         .         .                      .
# 29573G/A          99,115,2,2  MODERATE  MISSENSE  NON_SYNONYMOUS_CODING
# 29761A/G         181,225,3,3         .         .                      .
#
#                    GENE    CODON textual_variant  AF_delta
# textual_variant
# 1409C/T          orf1ab  Cat/Tat         1409C/T  0.038964
# 1821G/A          orf1ab  gGt/gAt         1821G/A  0.352701
# 1895G/A          orf1ab  Gta/Ata         1895G/A  0.000000
# 2407G/T          orf1ab  aaG/aaT         2407G/T  0.000000
# 3379A/G          orf1ab  gtA/gtG         3379A/G  0.023311
# ...                 ...      ...             ...       ...
# 29515T/A              N  gcT/gcA        29515T/A  0.084854
# 29515T/G              N  gcT/gcG        29515T/G  0.000000
# 29556A/G              .        .        29556A/G  0.022859
# 29573G/A          ORF10  Gtt/Att        29573G/A  0.000000
# 29761A/G              .        .        29761A/G  0.013329
#
# [82960 rows x 16 columns]

# %%
# Define an interactive scatterplot function

DF=df
HANDLER = {}

def scatterplot_interactive(min_af=0, min_af_delta=0, min_occurence=1):
    df = DF
    df = df[(df['AF'] >= min_af)]
    by_var = df.groupby(['POS', 'REF', 'ALT']).size()
    df.index = pd.MultiIndex.from_frame(df[['POS', 'REF', 'ALT']])
    df.loc[by_var.index, 'Occurence'] = by_var;
    df = df[(df['Occurence'] >= min_occurence) & (df['AF_delta'] >= min_af_delta)]


    def scatterplot(df, ax=None):
        markers = {".":"*", "MISSENSE":"^", "NONSENSE":"X", "SILENT":"o"}
        ax = sns.scatterplot(x='POS',y='AF',data=df[df['AF']>=0.05],hue='Sample',style='FUNCLASS',legend='brief',alpha=0.6,s=500,markers=markers, ax=plt.gca(), picker=True)
        i = 0
        for feature in record.features:
            if feature.type == 'gene':
                i += 1
                gene_name = feature.qualifiers['gene'][0]
                if gene_name.startswith('ORF'):
                    gene_name=gene_name[3:]
                if i % 2 == 0:
                    color ='tomato'
                    y = 0.01
                else:
                    color ='deepskyblue'
                    y = -0.01
                plt.hlines(y,feature.location._start.position, feature.location._end.position, linewidth=20, color=color)
                plt.text(feature.location._start.position+(feature.location._end.position-feature.location._start.position)//2, y, gene_name,horizontalalignment='center',verticalalignment='center',fontsize=15)
        plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
        return ax.figure

    plt.clf()
    scatterplot(df)

    # create and add an annotation object (a text label)
    def annotate(axis, text, x, y):
        text_annotation = Annotation(text, xy=(x, y), xycoords='data')
        axis.add_artist(text_annotation)


    # define the behaviour -> what happens when you pick a dot on the scatterplot by clicking close to it

    def onpick(event):
        # step 1: take the index of the dot which was picked
        if event.mouseevent.button in {'up', 'down'}:
            return
        ind = event.ind
        ax = plt.gca()

        # step 2: save the actual coordinates of the click, so we can position the text label properly
        label_pos_x = event.mouseevent.xdata
        label_pos_y = event.mouseevent.ydata

        # just in case two dots are very close, this offset will help the labels not appear one on top of each other
        offset = 0

        # if the dots are to close one to another, a list of dots clicked is returned by the matplotlib library
        for i in ind:
            # step 3: take the label for the corresponding instance of the data
            row = df.iloc[i,]
            label = "{row.POS} {row.REF}/{row.ALT}".format(row=row)

            # step 5: create and add the text annotation to the scatterplot
            annotate(
                ax,
                label,
                label_pos_x + offset,
                label_pos_y + offset
            )

            # step 6: force re-draw

            ax.figure.canvas.draw_idle()

            # alter the offset just in case there are more than one dots affected by the click
            offset += 0.05


    # connect the click handler function to the scatterplot
    fig = plt.gcf()
    if 'CID' in HANDLER:
        fig.canvas.mpl_disconnect(HANDLER['CID'])
    HANDLER['CID'] = fig.canvas.mpl_connect('pick_event', onpick)
    plt.show()

# %% [markdown]
# Let's have a look at the Allele Frequencies of intraindividual variants.

# %%
fig, ax = plt.subplots(figsize=(20, 7.5))
interactive(scatterplot_interactive,
            min_af=widgets.FloatSlider(min=0.0, max=1.0, value=0.05, step=0.01),
            min_occurence=widgets.IntSlider(min=1, step=1),
            min_af_delta=widgets.FloatSlider(min=0.0, max=1.0, value=0, step=0.01),
           )
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# interactive(children=(FloatSlider(value=0.05, description='min_af', max=1.0, step=0.01), FloatSlider(value=0.0…

# %% [markdown]
# There are 3 slides that control the scatterplot above. One can set the minimum allele frequecy for a variant to be plotted,
# the minimum allele frequency delta (the highest allele frequency minus the lowest allele frequency observed), and the min_occurence
# slider, which selects only vartiants that have been observed at least N times.
#
# At a minimum allele frequency of 0.05, allele frequency delta of 0.5 and a minimum occurence of 3 (meaning that variant has been sampled 3 times)
# we see multiple variants.
#
# 10779T/A for instance can be the major variant as well as the minor variant.

# %%
DELTA = 0.5


filtered_af_delta = df[df['AF_delta'] > DELTA].reset_index(drop=True).sort_values(['textual_variant', 'AF_delta'])
filtered_af_delta.style.bar(subset=['AF'],color='#d65f5f')
# Out:
# <style  type="text/css" >
#     #T_046dfb8c_77fc_11ea_af9d_acde48001122row0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 63.2%, transparent 63.2%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.3%, transparent 2.3%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.9%, transparent 1.9%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row4_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row5_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 97.9%, transparent 97.9%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row6_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 98.3%, transparent 98.3%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row7_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 97.5%, transparent 97.5%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row8_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.7%, transparent 0.7%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row9_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.9%, transparent 0.9%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row10_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.2%, transparent 3.2%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row11_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.2%, transparent 8.2%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row12_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 21.9%, transparent 21.9%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row13_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 98.5%, transparent 98.5%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row14_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 23.1%, transparent 23.1%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row15_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 13.5%, transparent 13.5%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row16_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 19.6%, transparent 19.6%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row17_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.1%, transparent 0.1%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row18_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.1%, transparent 0.1%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row19_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.4%, transparent 9.4%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row20_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 13.0%, transparent 13.0%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row21_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.1%, transparent 11.1%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row22_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.9%, transparent 20.9%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row23_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 82.9%, transparent 82.9%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row24_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.7%, transparent 0.7%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row25_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.4%, transparent 0.4%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row26_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.1%, transparent 0.1%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row27_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.9%, transparent 2.9%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row28_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.2%, transparent 0.2%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row29_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.2%, transparent 0.2%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row30_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.3%, transparent 0.3%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row31_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.9%, transparent 12.9%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row32_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.3%, transparent 0.3%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row33_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.1%, transparent 0.1%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row34_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.9%, transparent 0.9%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row35_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 94.6%, transparent 94.6%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row36_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 60.5%, transparent 60.5%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row37_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.2%, transparent 4.2%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row38_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }    #T_046dfb8c_77fc_11ea_af9d_acde48001122row39_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 50.1%, transparent 50.1%);
#         }    #T_046dfb8c_77fc_11ea_af9d
